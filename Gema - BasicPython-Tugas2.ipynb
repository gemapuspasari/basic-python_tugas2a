# %%
count = int (input("Berapa data pelanggan: "))

nama_pelanggan = []
umur_pelanggan = []

print("")
print("Masukkan data pelanggan")
print("")

for i in range (count):
  print ("Pelanggan ke {}". format (i+1))
  nama = input ("Nama: ")
  umur = int(input("Umur: "))

  nama_pelanggan.append(nama)
  umur_pelanggan.append(umur)

print("")
print("Pelanggan yang terdaftar adalah: ")
print("")
for i in range(len(nama_pelanggan)):
  print("Pelanggan {} berumur {}". format (nama_pelanggan [i], umur_pelanggan [i]))

# %%
#Nested Loop

print("Strukturnya")
for i in range(3):
  print("")
  print("i: {}". format (i))
  print("iterasi ke: {}". format (i+1))
  for j in range (3):
    print("j: {}". format(j))

print("")
print("Urutan Matrix")

for baris in range (5):
  for kolom in range (5):
    print("{}.{}". format (baris + 1, kolom + 1), end = "")
  print("")

print("")
print("Urutan angka")

count = 1
for baris in range (5):
  for kolom in range (5):
    print (count, end = "")
    count = count + 1
  print()

# %%
# Soal Bonus

string = ""

x = int(input("Masukkan angka: "))
bar = x

# Looping Baris
while bar >= 0:
# Looping Kolom Spasi Kosong
  kol = bar
  while kol >= 0:
    string = string + ""
    kol = kol - 1

    # Looping Kolom Bintang Sisi Kiri
    kiri = 1
    while kiri < ( x - (bar - 1)):
      string = string + "*"
      kiri = kiri + 1

    #Looping Kolom Bintang Sisi Kanan
    kanan = 1
    while kanan < kiri - 1:
      string = string + "*"
      kanan = kanan + 1

    string = string +"\n"
    bar = bar - 1

print (string)
# Out:
# Masukkan angka: 3
#
# *
# ***
# *****

# %%
mylist = []
mylist.append(1)
mylist.append(2)
mylist.append(3)
mylist.append(100)

print(mylist)
print(len(mylist))
print(mylist[3])

mylist2 = []
mylist2.append("a")
mylist2.append("b")

print(mylist2)
print(len(mylist2))

for x in mylist:
  print("Value: " + str (x))
# Out:
# [1, 2, 3, 100]
# 4
# 100
# ['a', 'b']
# 2
# Value: 1
# Value: 2
# Value: 3
# Value: 100

# %%
# Dictionary
pelanggan = {
    "nama": "fawwaz",
    "umur": 21
}

pelanggan_2 = {
    "nama": "andi",
    "umur": 18
}

print("Nama: {}".format(pelanggan["nama"]))
print("Umur: {}".format(pelanggan["umur"]))

# change value of dictionary
pelanggan["umur"] = 22

print("Nama: {}".format(pelanggan["nama"]))
print("Umur: {}".format(pelanggan["umur"]))

# loop through dictionary
for x in pelanggan:
  print(x)
  print(pelanggan[x])
  print(pelanggan_2[x])

#list of dictionary
daftar_pelanggan = []
daftar_pelanggan.append(pelanggan)
daftar_pelanggan.append(pelanggan_2)

for pelanggan in daftar_pelanggan:
  print("Nama: {}".format(pelanggan["nama"]))
  print("Umur: {}".format(pelanggan["umur"]))
# Out:
# Nama: fawwaz
# Umur: 21
# Nama: fawwaz
# Umur: 22
# nama
# fawwaz
# andi
# umur
# 22
# 18
# Nama: fawwaz
# Umur: 22
# Nama: andi
# Umur: 18

# %%
# Delete dictionary
data = {'Name': 'Zara', 'Age': 7, 'Class': 'First'}

del data ['Name']

print(data)
print("dict['Age']: ", data ['Age'])
print("dict['School']: ", data['Class'])

# %%
# Delete dictionary
data = {'Name': 'Zara', 'Age': 7, 'Class': 'First'}

data.clear()


print(data)
#print("dict['Age']: ", data ['Age'])
#print("dict['School']: ", data['Class'])

# %%
def square(size):
  for i in range(size):
    if i == 0 or i == (size - 1): 
      print("*" * size)
     
    else:
        print("*" + (" * " * (size - 2)) + "")
square(3)
# Out:
# ***
# * *
# ***

# %%
def square (size):
  for i in range (size):
    if i == 0 or i == size -1:
      print("*" * size)
    else:
        print("*" + ("" * (size-2)) + "*")
square(3)
# Out:
# ***
# **
# ***

# %%
def square (size):
  for i in range (size):
    if i == 0 or i == size -1:
      print("*" * size)
    else:
      print("" + ("*" * (size-2)) + "*")
square(3)
# Out:
# ***
# **
# ***

# %%
#1. Buatlah sebuah program yang dapat menyimpan kontak dan juga menampilkan kontak-kontak
tersebut. Setiap kontak terdiri dari nama dan nomor telepon . Saat menjalankan program,
program akan menampilkan pesan sambutan dan juga menampilkan menu. Program akan secara
otomatis kembali menu apabila user telah selesai melihat kontak ataupun menambahkan
kontak.
Selamat datang!
--- Menu ---
1. Daftar Kontak
2. Tambah Kontak
3. Keluar
Program akan meminta user untuk memilih menu yang disediakan.
Pilih menu:(input dari user)
Jika user memilih menu 1, maka program akan menampilkan seluruh data kontak yang telah
disimpan. Contoh apabila program memiliki hanya 2 data:
Daftar kontak:
Nama: Fawwaz
No Telepon: 08123456789
Nama: John
No Telepon: 08987654321
Jika user memilih menu 2, maka program akan meminta user untuk memasukkan data yang
dibutuhkan untuk menambahkan kontak.
Nama:
No Telepon:
Apabila kontak sudah ditambahkan, berikan konfirmasi kepada user bahwa kontak telah berhasil
ditambahkan.
Kontak berhasil ditambahkan
Jika user memilih menu 3, maka program akan berhenti dan menampilkan pesan ke layar.
Program selesai, sampai jumpa!
Jika user memasukkan pilihan menu yang tidak tersedia, maka program akan menampilkan
pesan, kemudian kembali ke menu.
Menu tidak tersedia

# %%
# greeting
print ("SELAMAT DATANG!")

# pilih menu
# 1 -> seluruh data kontak yang telah disimpan
# 2 -> masukkan data untuk menambah kontak # kontak berhasil ditambahkan
# 3 -> keluar

#x = "Daftar Kontak"
#y = "Tambah Kontak"
#z = "KELUAR"

print (" ---Menu--- ")
print ("1. Daftar Kontak")
print ("2. Tambah Kontak")
print ("3. Keluar")

# Siapkan Fungsi
tampilkan_kontak()
tambah_kontak()



int (input("Pilih menu: "))

# bagian susahnya

menu = int (input("Pilih Menu: "))

#if menu == 1
  #print (x)
#elif menu == 2
  #print (y)
#else:
   #print (z)


# menu 1 -> menampilkan seluruh data kontak yang telah disimpan

# tampilkan_kontak() looping for 

#k = tampilkan_kontak


kontak_1 = {
    "Nama": "Ben",
    "Umur": 36,
    "Pekerjaan": "Aktor",
    "No. Telepon": 5556789
}

kontak_2 = {
    "Nama": "Adam",
    "Umur": 32,
    "Pekerjaan": "Sutradara",
    "No. Telepon": 5551234,
}

print("Nama: {}".format(kontak_1["Nama"]))
print("Umur: {}".format(kontak_1["Umur"]))
print("Pekerjaan: {}".format(kontak_1["Pekerjaan"]))
print("No.Telepon: {}".format(kontak_1["No. Telepon"]))


print("Nama: {}".format(kontak_2["Nama"]))
print("Umur: {}".format(kontak_2["Umur"]))
print("Pekerjaan: {}".format(kontak_2["Pekerjaan"]))
print("No.Telepon: {}".format(kontak_2["No. Telepon"]))

# loop through dictionary
x = kontak

for x in kontak:
  print(x)
  print(kontak_1[x])
  print(kontak_2[x])

#list of dictionary
daftar_pelanggan = []
daftar_pelanggan.append(pelanggan)
daftar_pelanggan.append(pelanggan_2)

for pelanggan in daftar_pelanggan:
  print("Nama: {}".format(pelanggan["nama"]))
  print("Umur: {}".format(pelanggan["umur"]))
# Out:
# SELAMAT DATANG!
#  ---Menu---
# 1. Daftar Kontak
# 2. Tambah Kontak
# 3. Keluar
# Pilih menu: 3
# Pilih Menu: 2
# Nama: Ben
# Umur: 36
# Pekerjaan: Aktor
# No.Telepon: 5556789
# Nama: Adam
# Umur: 32
# Pekerjaan: Sutradara
# No.Telepon: 5551234
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-32324b5ffc30> in <module>()
#      62
#      63 # loop through dictionary
# ---> 64 x = kontak
#      65
#      66 for x in kontak:
#
# NameError: name 'kontak' is not defined

# %%
nilaiteori = float (input("Nilai Ujian Teori :"))
nilaipraktek = float (input("Nilai Ujian Praktek :"))
if nilaiteori >= 70 and nilaipraktek >= 70:
  print ("Selamat, anda lulus!")
elif nilaiteori <= 70 and nilaipraktek < 70:
  print ("Anda harus mengulang ujian praktek.")
elif nilaiteori < 70 and nilaipraktek<= 70:
  print ("Anda harus mengulang ujian teori.")
else:
 
  print ("Anda harus mengulang ujian teori dan praktek.")

# %%
# greetings *****
print ("SELAMAT DATANG!")
print ("")
print (" ---Menu--- ")
print ("1. Daftar Kontak")
print ("2. Tambah Kontak")
print ("3. Keluar")
print ("")
int (input("Pilih menu: "))

#Dictionary ****

def tampilkan_kontak 
(
  kontak_1 = {"Nama": "Ben", "Umur": 36, "Pekerjaan": "Aktor", "No. Telepon": 5556789},
  kontak_2 = {"Nama": "Adam", "Umur": 32,"Pekerjaan": "Sutradara","No. Telepon": 5551234})

print(tampilkan_kontak)


#print("Nama: {}".format(kontak_1["Nama"]))
#print("Umur: {}".format(kontak_1["Umur"]))
#print("Pekerjaan: {}".format(kontak_1["Pekerjaan"]))
#print("No.Telepon: {}".format(kontak_1["No. Telepon"]))


#print("Nama: {}".format(kontak_2["Nama"]))
#print("Umur: {}".format(kontak_2["Umur"]))
#print("Pekerjaan: {}".format(kontak_2["Pekerjaan"]))

# Loop through dictionary *****
# loop through dictionary
for x in tampilkan_kontak:
  print(x)
  print(kontak_1[x])
  print(kontak_2[x])

#list of dictionary
#tampilkan_kontak = []
#tampilkan_kontak.append(kontak_1)
#tampilkan_kontak.append(kontak_2)

#for pelanggan in tampilkan_kontak:
  #print("Nama: {}".format(kontak_1["Nama"]))
  #print("Umur: {}".format(kontak_1["Umur"]))
  #print("Pekerjaan: {}".format(kontak_1["Pekerjaan"]))
  #print("No.Telepon: {}".format(kontak_1["No. Telepon"])) 
  #print("Nama: {}".format(kontak_2["Nama"]))
  #print("Umur: {}".format(kontak_2["Umur"]))
  #print("Pekerjaan: {}".format(kontak_2["Pekerjaan"]))
  #print("No.Telepon: {}".format(kontak_2["No. Telepon"])) 

#menu= int (input("Pilih menu :"))

#if menu == 1
  #print (tampilkan_kontak())
#elif menu == 2
  #print (tambahkan_kontak())
#else:
   #print ("Keluar")
# Out:
#   File "<ipython-input-143-5459311b4321>", line 15
#     kontak_2 = {"Nama": "Adam", "Umur": 32,"Pekerjaan": "Sutradara","No. Telepon": 5551234})
#                                                                                             ^
# SyntaxError: invalid syntax
